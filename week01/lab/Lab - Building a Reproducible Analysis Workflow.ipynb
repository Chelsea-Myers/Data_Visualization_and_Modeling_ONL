# %% [markdown]
# # Lab: Building a Reproducible Analysis Workflow
#
# Choose your own documented dataset and apply the seven-step workflow from the Pokémon lecture. You may reuse the dataset from the visual thinking lab, but ask a new analytical question.

# %% [markdown]
# ## Learning goals
#
# - Formulate a question that can be answered with data.
# - Inspect and document a chosen dataset.
# - Select, group, summarize, or calculate features with Pandas.
# - Check results and distinguish evidence, conclusions, and limitations.

# %% [markdown]
# ## The reproducible analysis workflow
#
# 1. **Question:** What do you want to learn?
# 2. **Data:** Which observations and features can answer it?
# 3. **Operation:** What should the code calculate?
# 4. **Check:** How can you detect an error?
# 5. **Evidence:** Which result answers the question?
# 6. **Conclusion:** What claim is supported?
# 7. **Limitation:** What should readers avoid concluding?

# %% [markdown]
# ## Using AI tools responsibly
#
# You may use AI to ask questions, debug code, or receive feedback. You remain responsible for understanding the work and checking suggestions. Disclose whether you used AI in the final reflection.

# %% [markdown]
# ## Your own investigation

# %% [markdown]
# ## Find a dataset
#
# You may reuse the dataset you selected for the visual thinking lab or find another documented CSV dataset. Choose a research question requiring filtering, grouping, or a calculated feature; do not simply repeat the earlier single-feature charts. [Kaggle](https://www.kaggle.com/datasets) is one possible source, but you may use another reputable source. Choose a dataset that:
#
# - has a clearly identified publisher or creator;
# - includes documentation explaining the observations and features;
# - contains at least one categorical and one quantitative feature;
# - is appropriate to share in a class assignment;
# - does not contain private or personally identifying information; and
# - is small enough to run comfortably in this notebook.
#
# Save the CSV in the notebook's `data` folder before continuing.

# %% [markdown]
# **What is the dataset's title, publisher or creator, and direct source URL?**
#
# Your answer:

# %% [markdown]
# **What does one row represent?**
#
# Your answer:

# %% [markdown]
# ## Step 1: Question
#
# Formulate one research question that can be answered with your dataset. The question must require a calculation or comparison, not merely looking up one value.

# %% [markdown]
# **What is your research question?**
#
# Your answer:

# %% [markdown]
# **Before calculating, what do you predict the result will be, and why?**
#
# Your answer:

# %% [markdown]
# ## Step 2: Data
#
# Read your CSV into a descriptively named DataFrame ending in `_df`. Display the first and last five rows, information about the DataFrame, and the missing-value count for every feature.

# %%
# Write your code here.

# %% [markdown]
# **Which observations and features will you use to answer your question?**
#
# Your answer:

# %% [markdown]
# ## Step 3: Operation
#
# Write the code needed to prepare, filter, group, summarize, or sort the data. Store the final evidence in a clearly named object and display it.

# %%
# Write your code here.

# %% [markdown]
# **Explain how your operations connect the selected data to your research question.**
#
# Your answer:

# %% [markdown]
# ## Step 4: Check
#
# Write at least one check that could reveal an error in your analysis, then display its result.

# %%
# Write your code here.

# %% [markdown]
# **What did you check, and did the result meet your expectation?**
#
# Your answer:

# %% [markdown]
# ## Step 5: Evidence

# %% [markdown]
# **Which specific value or comparison in your output answers the question?**
#
# Your answer:

# %% [markdown]
# ## Step 6: Conclusion

# %% [markdown]
# **What conclusion is supported by the evidence, and how does it compare with your prediction?**
#
# Your answer:

# %% [markdown]
# ## Step 7: Limitation

# %% [markdown]
# **What should a reader avoid concluding from your analysis, and why?**
#
# Your answer:

# %% [markdown]
# ## AI-use reflection

# %% [markdown]
# **State whether you used an AI tool. If you did, describe one suggestion you checked and what you accepted, changed, or rejected. If you did not, state that you did not use one.**
#
# Your response:

# %% [markdown]
# ## Submission checklist
#
# Before submitting, confirm that all cells run in order, the independent dataset and its source are included, every answer is complete, numerical claims match the output, conclusions are appropriately limited, and the AI-use reflection is complete.
